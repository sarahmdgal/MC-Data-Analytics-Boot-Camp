# %%
import numpy as np
import pandas as pd
filename = "datasets/diamonds.csv"
df = pd.read_csv(filename)

df.head(107)
# Out:
#      Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0             1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1             2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2             3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3             4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4             5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5             6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6             7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7             8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8             9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9            10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10           11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %%
df['price'].sum()
# Out:
# 212135217

# %%
df['price'].mean()
# Out:
# 3932.799721913237

# %%
df['price'].mode()
# Out:
# 0    605
# dtype: int64

# %%
df['carat'].mean()
# Out:
# 0.7979397478679852

# %%
df['price'].std()
# Out:
# 3989.4397381463023

# %%
df.count()
# Out:
# Unnamed: 0    53940
# carat         53940
# cut           53940
# color         53940
# clarity       53940
# depth         53940
# table         53940
# price         53940
# x             53940
# y             53940
# z             53940
# dtype: int64

# %%
df.groupby('price')

# %%
df['carat'].groupby(df['price']).mean()
# Out:
# price
# 326      0.220000
# 327      0.230000
# 334      0.290000
# 335      0.310000
# 336      0.240000
# 337      0.240000
# 338      0.230000
# 339      0.300000
# 340      0.230000
# 342      0.220000
# 344      0.310000
# 345      0.260000
# 348      0.300000
# 351      0.300000
# 352      0.230000
# 353      0.283333
# 354      0.230000
# 355      0.240000
# 357      0.242500
# 358      0.260000
# 360      0.290000
# 361      0.272500
# 362      0.242500
# 363      0.298000
# 364      0.233333
# 365      0.320000
# 366      0.330000
# 367      0.225294
# 368      0.300000
# 369      0.230000
#            ...
# 18717    2.180000
# 18718    1.700000
# 18729    1.510000
# 18730    1.720000
# 18731    2.020000
# 18735    1.940000
# 18736    2.010000
# 18741    2.010000
# 18745    2.360000
# 18756    2.610000
# 18757    2.030000
# 18759    2.000000
# 18760    2.080000
# 18766    2.550000
# 18768    1.710000
# 18777    1.510000
# 18779    2.060000
# 18780    1.600000
# ...

# %%
pd.pivot_table(df, index=['cut'])
# Out:
#              Unnamed: 0     carat      depth        price      table  \
# cut
# Fair       24147.357764  1.046137  64.041677  4358.757764  59.053789
# Good       24774.931309  0.849185  62.365879  3928.864452  58.694639
# Ideal      29047.630736  0.702837  61.709401  3457.541970  55.951668
# Premium    25600.209049  0.891955  61.264673  4584.257704  58.746095
# Very Good  26097.313193  0.806381  61.818275  3981.759891  57.956150
#
#                   x         y         z
# cut
# Fair       6.246894  6.182652  3.982770
# Good       5.838785  5.850744  3.639507
# Ideal      5.507451  5.520080  3.401448
# Premium    5.973887  5.944879  3.647124
# Very Good  5.740696  5.770026  3.559801

# %%
pd.pivot_table(df, values=['price'], index=['cut'])
# Out:
#                  price
# cut
# Fair       4358.757764
# Good       3928.864452
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891

# %%
pd.pivot_table(df, values=['price', 'clarity'], index=['cut'])
# Out:
#                  price
# cut
# Fair       4358.757764
# Good       3928.864452
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891

# %%
pd.pivot_table(df, values=['cut', 'clarity', 'table'], index=['price'])
# Out:
#            table
# price
# 326    58.000000
# 327    65.000000
# 334    58.000000
# 335    58.000000
# 336    57.000000
# 337    58.000000
# 338    61.000000
# 339    55.000000
# 340    56.000000
# 342    61.000000
# 344    54.000000
# 345    60.000000
# 348    54.000000
# 351    56.250000
# 352    55.000000
# 353    60.333333
# 354    58.000000
# 355    57.000000
# 357    57.875000
# 358    56.000000
# 360    55.500000
# 361    58.250000
# 362    56.500000
# 363    57.200000
# 364    53.666667
# 365    59.000000
# 366    54.000000
# 367    58.176471
# 368    58.333333
# 369    58.000000
# ...          ...
# 18717  60.000000
# 18718  59.000000
# 18729  57.000000
# 18730  60.000000
# 18731  59.000000
# 18735  58.000000
# 18736  57.000000
# 18741  58.000000
# 18745  58.000000
# 18756  56.000000
# 18757  55.800000
# 18759  60.000000
# 18760  60.000000
# 18766  62.000000
# 18768  55.000000
# 18777  59.000000
# 18779  55.000000
# 18780  56.000000
# 18781  60.000000
# 18784  59.000000
# ...

# %%
df['carat'].count
# Out:
# <bound method Series.count of 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
# 5        0.24
# 6        0.24
# 7        0.26
# 8        0.22
# 9        0.23
# 10       0.30
# 11       0.23
# 12       0.22
# 13       0.31
# 14       0.20
# 15       0.32
# 16       0.30
# 17       0.30
# 18       0.30
# 19       0.30
# 20       0.30
# 21       0.23
# 22       0.23
# 23       0.31
# 24       0.31
# 25       0.23
# 26       0.24
# 27       0.30
# 28       0.23
# 29       0.23
#          ...
# 53910    0.70
# 53911    0.57
# 53912    0.61
# 53913    0.80
# 53914    0.84
# 53915    0.77
# 53916    0.74
# 53917    0.90
# 53918    0.76
# 53919    0.76
# 53920    0.70
# 53921    0.70
# 53922    0.70
# 53923    0.73
# 53924    0.73
# 53925    0.79
# 53926    0.71
# 53927    0.79
# 53928    0.79
# 53929    0.71
# 53930    0.71
# 53931    0.71
# 53932    0.70
# 53933    0.70
# 53934    0.72
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# ...

# %%
df['clarity'].count()
# Out:
# 53940

# %%
df['x'].std()
# Out:
# 1.1217607467924422

# %%
pd.pivot_table(df, values=['x', 'y', 'z'], index=df['price'])
# Out:
#               x         y         z
# price
# 326    3.920000  3.910000  2.370000
# 327    4.050000  4.070000  2.310000
# 334    4.200000  4.230000  2.630000
# 335    4.340000  4.350000  2.750000
# 336    3.945000  3.970000  2.475000
# 337    3.970000  3.945000  2.510000
# 338    4.000000  4.050000  2.390000
# 339    4.250000  4.280000  2.730000
# 340    3.930000  3.900000  2.460000
# 342    3.880000  3.840000  2.330000
# 344    4.350000  4.370000  2.710000
# 345    4.085000  4.085000  2.475000
# 44.0  1.00  53.0  4032          NaN  NaN  NaN  NaN
# 50.8  1.43  60.0  6727          NaN  NaN  NaN  NaN
# 51.0  0.30  67.0  945           NaN  NaN  NaN  NaN
# 52.2  0.70  65.0  1895          NaN  NaN  NaN  NaN
# 52.3  0.37  61.0  1166          NaN  NaN  NaN  NaN
# 52.7  0.56  70.0  1293          NaN  NaN  NaN  NaN
# 53.0  1.02  63.0  2856          NaN  NaN  NaN  NaN
# 53.1  0.96  63.0  2815          NaN  NaN  NaN  NaN
# 53.2  0.35  62.0  1011          NaN  NaN  NaN  NaN
#       1.26  61.0  4966          NaN  NaN  NaN  NaN
# 53.3  0.98  67.0  2855          NaN  NaN  NaN  NaN
# 53.4  0.73  65.0  2164          NaN  NaN  NaN  NaN
# 53.8  1.08  63.0  4790          NaN  NaN  NaN  NaN
# 54.0  0.34  56.0  1012          NaN  NaN  NaN  NaN
# 54.2  0.31  63.0  814           NaN  NaN  NaN  NaN
# ...

# %%
pd.pivot_table(df, values=['depth', 'table'], index=['price'])
# Out:
#            depth      table
# price
# 326    60.650000  58.000000
# 327    56.900000  65.000000
# 334    62.400000  58.000000
# 335    63.300000  58.000000
# 336    62.550000  57.000000
# 337    63.500000  58.000000
# 338    59.400000  61.000000
# 339    64.000000  55.000000
# 340    62.800000  56.000000
# 342    60.400000  61.000000
# 344    62.200000  54.000000
# 345    60.550000  60.000000
# 348    62.000000  54.000000
# 351    63.300000  56.250000
# 352    63.800000  55.000000
# 353    59.500000  60.333333
# 354    60.400000  58.000000
# 355    62.500000  57.000000
# 357    61.912500  57.875000
# 358    61.900000  56.000000
# 360    61.750000  55.500000
# 361    61.200000  58.250000
# 362    62.525000  56.500000
# 363    62.260000  57.200000
# 364    62.100000  53.666667
# 365    62.200000  59.000000
# 366    62.400000  54.000000
# 367    61.541176  58.176471
# 368    62.100000  58.333333
# 369    62.700000  58.000000
# ...          ...        ...
# 18717  61.200000  60.000000
# ...

# %%
pd.pivot_table(df, values=['depth', 'table'], index=['price']).mean()
# Out:
# depth    61.707768
# table    57.662686
# dtype: float64

# %%
pd.pivot_table(df, values=['depth', 'table'], index=['price']).mode()
# Out:
#    depth  table
# 0   62.0   58.0

# %%
pd.pivot_table(df, values=['depth', 'table'], index=['price']).std()
# Out:
# depth    1.073050
# table    1.624959
# dtype: float64

# %%
pd.pivot_table(df, values=['depth', 'table'], index=['price']).median()
# Out:
# depth    61.754196
# table    57.571429
# dtype: float64

# %%
pd.pivot_table(df, values=['depth', 'table'], index=['price']).describe()
# Out:
#               depth         table
# count  11602.000000  11602.000000
# mean      61.707768     57.662686
# std        1.073050      1.624959
# min       53.200000     52.000000
# 25%       61.200000     56.666667
# 50%       61.754196     57.571429
# 75%       62.300000     58.556746
# max       70.600000     70.000000
